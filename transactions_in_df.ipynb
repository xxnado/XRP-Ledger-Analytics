# %% [markdown]
# ## Getting the data from an API to the DataFrame

# %% [markdown]
# Retrieving the information from the last 10 ledgers

# %%
import requests
import json
import pandas as pd

# Ripple API endpoint
url = "https://s2.ripple.com:51234/"  # Alternative Ripple server

# First, get the latest validated ledger index
initial_payload = {
    "method": "ledger_current",
    "params": [{}]
}

# Send the request to get the latest validated ledger
response = requests.post(url, json=initial_payload)
latest_ledger_index = 90588996

# Define the number of ledgers to retrieve
num_ledgers = 10

# Initialize list to store ledger data
ledger_data = []

# For loop to retrieve information for the last 3 ledgers
for i in range(num_ledgers):
    ledger_index = str(int(latest_ledger_index) - i)  # Move backwards in the ledger sequence
    print(f"Retrieving Ledger Index: {ledger_index}")

    # Create JSON request payload for the ledger
    payload = {
        "method": "ledger",
        "params": [
            {
                "ledger_index": ledger_index,
                "transactions": True,
                "expand": True
            }
        ]
    }

    # Send the request
    response = requests.post(url, json=payload)

    # Process the response
    try:
        response_json = response.json()  # Try to load the response as JSON
        ledger_info = response_json.get("result", {}).get("ledger", {})

        # Extract information for each transaction in the ledger
        if "transactions" in ledger_info:
            for tx in ledger_info["transactions"]:
                ledger_data.append({
                    "LedgerSequence": ledger_info.get("ledger_index"),
                    "CloseTime": ledger_info.get("close_time_human"),
                    "TransactionType": tx.get("TransactionType"),
                    "Account": tx.get("Account"),
                    "Fee": tx.get("Fee"),
                    "TransactionResult": tx.get("metaData", {}).get("TransactionResult"),
                    "TakerGets": tx.get("TakerGets"),
                    "TakerPays": tx.get("TakerPays"),
                    "Issuer": tx.get("TakerPays", {}).get("issuer") if isinstance(tx.get("TakerPays"), dict) else None,
                    "Currency": tx.get("TakerPays", {}).get("currency") if isinstance(tx.get("TakerPays"), dict) else None,
                    "Sequence": tx.get("Sequence"),
                    "OfferSequence": tx.get("OfferSequence"),
                    "OwnerCount": tx.get("OwnerCount"),
                    "Flags": tx.get("Flags")
                })

    except json.JSONDecodeError:
        print(f"Error: The response for ledger {ledger_index} is not a valid JSON.")
        print("Raw response from server:")
        print(response.text)

# Convert the collected data to a pandas DataFrame
df = pd.DataFrame(ledger_data)
# Out:
# Retrieving Ledger Index: 90588996
# Retrieving Ledger Index: 90588995
# Retrieving Ledger Index: 90588994
# Retrieving Ledger Index: 90588993
# Retrieving Ledger Index: 90588992
# Retrieving Ledger Index: 90588991
# Retrieving Ledger Index: 90588990
# Retrieving Ledger Index: 90588989
# Retrieving Ledger Index: 90588988
# Retrieving Ledger Index: 90588987

# %%
df
# Out:
#     LedgerSequence                           CloseTime TransactionType  \
# 0         90588996  2024-Sep-07 14:05:51.000000000 UTC     OfferCancel
# 1         90588996  2024-Sep-07 14:05:51.000000000 UTC         Payment
# 2         90588996  2024-Sep-07 14:05:51.000000000 UTC         Payment
# 3         90588996  2024-Sep-07 14:05:51.000000000 UTC     OfferCancel
# 4         90588996  2024-Sep-07 14:05:51.000000000 UTC         Payment
# ..             ...                                 ...             ...
# 682       90588987  2024-Sep-07 14:05:20.000000000 UTC     OfferCreate
# 683       90588987  2024-Sep-07 14:05:20.000000000 UTC     OfferCreate
# 684       90588987  2024-Sep-07 14:05:20.000000000 UTC     OfferCreate
# 685       90588987  2024-Sep-07 14:05:20.000000000 UTC     OfferCreate
# 686       90588987  2024-Sep-07 14:05:20.000000000 UTC     OfferCreate
#
#                                 Account Fee TransactionResult  \
# 0    rMffDj93JAQvogvJ2k8196DeAt5HcpdDQC  12        tesSUCCESS
# 1    rajaw3L7R7hgz8F1VVAobVVPnC3Vujvvhb  10        tesSUCCESS
# 2    rwjyDXa3YsdZUJcJSDkyRRvt1qwPfxVNKY  25        tesSUCCESS
# 3    rJtj42u8QPQWcPiwF3B8sNPb2GMo9gmNub  20        tesSUCCESS
# 4    rapido5rxPmP4YkMZZEeXSHqWefxHEkqv6  10        tesSUCCESS
# ..                                  ...  ..               ...
# 682   rogue5HnPRSszD9CWGSUz8UGHMVwSSKF6  10        tesSUCCESS
# 683   rogue5HnPRSszD9CWGSUz8UGHMVwSSKF6  10        tesSUCCESS
# 684  rapido5rxPmP4YkMZZEeXSHqWefxHEkqv6  10        tesSUCCESS
# 685  rapido5rxPmP4YkMZZEeXSHqWefxHEkqv6  10        tesSUCCESS
# 686  rh3VLyj1GbQjX7eA15BwUagEhSrPHmLkSR  15        tesSUCCESS
#
#                                              TakerGets  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 682  {'currency': '42495478000000000000000000000000...
# 683  {'currency': 'XDX', 'issuer': 'rMJAXYsbNzhwp7F...
# 684  {'currency': 'RLT', 'issuer': 'rUetS7kbVYJZ76z...
# 685  {'currency': '42495478000000000000000000000000...
# 686  {'currency': 'CNY', 'issuer': 'rJ1adrpGS3xsnQM...
#
#                                              TakerPays  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 682  {'currency': 'XDX', 'issuer': 'rMJAXYsbNzhwp7F...
# 683  {'currency': 'OVO', 'issuer': 'r3jQzqfGVagsWNb...
# 684  {'currency': 'MAG', 'issuer': 'rXmagwMmnFtVet3...
# 685  {'currency': 'RLT', 'issuer': 'rUetS7kbVYJZ76z...
# 686                                        20065821778
#
#                                  Issuer Currency   Sequence  OfferSequence  \
# 0                                  None     None   76197080     76197076.0
# 1                                  None     None   89656972            NaN
# 2                                  None     None   91310024            NaN
# 3                                  None     None   90559518     90559517.0
# 4                                  None     None   18076201            NaN
# ..                                  ...      ...        ...            ...
# 682  rMJAXYsbNzhwp7FfYnAsYP5ty3R9XnurPo      XDX   11370226            NaN
# 683  r3jQzqfGVagsWNbSxMJpQV8VK7jHHmdv5j      OVO   11370227            NaN
# 684   rXmagwMmnFtVet3uL26Q2iwk287SRvVMJ      MAG   18076094            NaN
# 685  rUetS7kbVYJZ76za5ywa1DgViNZMgT9Bvq      RLT   18076093            NaN
# 686                                None     None  139700403    139700400.0
#
#     OwnerCount         Flags
# 0         None  0.000000e+00
# 1         None           NaN
# 2         None  2.147484e+09
# 3         None  0.000000e+00
# 4         None  1.310720e+05
# ..         ...           ...
# 682       None  6.553600e+05
# 683       None  6.553600e+05
# 684       None  6.553600e+05
# 685       None  6.553600e+05
# 686       None  0.000000e+00
#
# [687 rows x 14 columns]

# %% [markdown]
# Showing the raw result for one of the ledgers

# %%
import requests
import json

# Definieren Sie den Ripple API-Endpunkt
url = "https://s2.ripple.com:51234/"  # Alternativer Ripple Server

# Ledger-Index, den Sie abfragen möchten
ledger_index = "90588710"  # Verwenden Sie "validated" für den letzten validierten Ledger

# Erstellen der JSON-Anfrage
payload = {
    "method": "ledger",
    "params": [
        {
            "ledger_index": ledger_index,
            "transactions": True,
            "expand": True
        }
    ]
}

# Senden der Anfrage
response = requests.post(url, json=payload)

# Überprüfen der Antwort
try:
    response_json = response.json()  # Versuchen, die Antwort als JSON zu laden
    print(json.dumps(response_json, indent=2))
except json.JSONDecodeError:
    print("Fehler: Die Antwort ist kein gültiges JSON.")
    print("Rohantwort vom Server:")
    print(response.text)  # Druckt die tatsächliche Antwort, die vom Server empfangen wurde
# Out:
# {
#   "result": {
#     "ledger_hash": "0BA0AD93CC3DFA383D044E5261EE510443E69836A326BA34E48EF4E0DEF722A2",
#     "ledger_index": 90588710,
#     "validated": true,
#     "ledger": {
#       "account_hash": "42CAA52E085441820BC5CEE134DF633ABD75E1B66AF187863CDF8DF96F6887AC",
#       "close_flags": 0,
#       "close_time": 779032060,
#       "close_time_human": "2024-Sep-07 13:47:40.000000000 UTC",
#       "close_time_resolution": 10,
#       "close_time_iso": "2024-09-07T13:47:40Z",
#       "ledger_hash": "0BA0AD93CC3DFA383D044E5261EE510443E69836A326BA34E48EF4E0DEF722A2",
#       "parent_close_time": 779032051,
#       "parent_hash": "E6F6F1744AA3C22C548CB6471575DEEE1C81A9621401E226D8A1055A5DEC48FA",
#       "total_coins": "99987209508488756",
#       "transaction_hash": "F72778273C01FDB119D7A1A2D9FDD5AB030B67D3DEA95C6D8B7D3985710D0B6C",
#       "ledger_index": "90588710",
#       "closed": true,
#       "transactions": [
#         {
#           "Account": "rsUG78xTs7LXJBpeUVvdkFgDrS3s9as4PK",
#           "Amount": "90",
#           "Destination": "rMo8bT3qWkvyNvp4UQUfFEAKYv921aGdhk",
#           "DestinationTag": 1111187,
#           "Fee": "10",
#           "Sequence": 89652522,
#           "SigningPubKey": "ED7C2CB6B0D1CC310CCE3CC955913FF9DB8A1E3D6D389804114EF56D610553F99F",
#           "TransactionType": "Payment",
#           "TxnSignature": "668B290AB43C8B7D359570B3988355FB1C7824B8FE6AA6665CA7E9DD4938E50CB5A88A9F92D63065B9684B23A8F6FC3804344E7B9AF26B5C949C92242F03A50C",
#           "hash": "0157CC094A26CC92CAD66799029F9523E46DEE5DF09ECB4FBC5FFD5B65C0AA2A",
#           "DeliverMax": "90",
#           "metaData": {
#             "AffectedNodes": [
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Account": "rMo8bT3qWkvyNvp4UQUfFEAKYv921aGdhk",
#                     "Balance": "13193420",
#                     "Flags": 0,
#                     "OwnerCount": 0,
#                     "Sequence": 89531849
#                   },
#                   "LedgerEntryType": "AccountRoot",
#                   "LedgerIndex": "2A9DF02FF78FCCE946B77372B25D9C6F875895CEE6AAC1D37A7158BAA3E9BBDC",
#                   "PreviousFields": {
#                     "Balance": "13193330"
#                   },
#                   "PreviousTxnID": "2FD42EEE5E4215897531E5B2C396A287C8705BD90D6E819EF731862459BF15EA",
#                   "PreviousTxnLgrSeq": 90588710
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Account": "rsUG78xTs7LXJBpeUVvdkFgDrS3s9as4PK",
#                     "Balance": "181631179",
#                     "Flags": 0,
#                     "OwnerCount": 0,
#                     "Sequence": 89652523
#                   },
#                   "LedgerEntryType": "AccountRoot",
#                   "LedgerIndex": "55FD944999718BAD9A0246EB6700ED1FEEF5882981C1E79DA779B02A61FB1995",
#                   "PreviousFields": {
#                     "Balance": "181631279",
#                     "Sequence": 89652522
#                   },
#                   "PreviousTxnID": "A82B5A7165D6006588E9B50982BF8AB6B9842AA43614AA14128236DBD8A5429A",
#                   "PreviousTxnLgrSeq": 90588685
#                 }
#               }
#             ],
#             "TransactionIndex": 46,
#             "TransactionResult": "tesSUCCESS",
#             "delivered_amount": "90"
#           }
#         },
#         {
#           "Account": "rapido5rxPmP4YkMZZEeXSHqWefxHEkqv6",
#           "Amount": {
#             "currency": "534F4C4F00000000000000000000000000000000",
#             "issuer": "rsoLo2S1kiGeCcn6hCUXVrCpGMWLrRrLZz",
#             "value": "0.02384580959249305"
#           },
#           "Destination": "rapido5rxPmP4YkMZZEeXSHqWefxHEkqv6",
#           "Fee": "10",
#           "Flags": 131072,
#           "LastLedgerSequence": 90588711,
#           "SendMax": "4014",
#           "Sequence": 18072355,
#           "SigningPubKey": "EDE30BA017ED458B9B372295863B042C2BA8F11AD53B4BDFB398E778CB7679146B",
#           "TransactionType": "Payment",
#           "TxnSignature": "EAE795F2466708FB0BE11A8EAD70B00D3E8D4FF5B536213E999CEEA0D7AC3951DCABD4F008E00B79DC2F765B164EEAF8AAA1474D3CBED974E61EDB855C4BAC07",
#           "hash": "09C6A57F813CDCD15C8365F02FEEA120E3F2BD4717AA816ED1B8B1F74EEC197D",
#           "DeliverMax": {
#             "currency": "534F4C4F00000000000000000000000000000000",
#             "issuer": "rsoLo2S1kiGeCcn6hCUXVrCpGMWLrRrLZz",
#             "value": "0.02384580959249305"
#           },
#           "metaData": {
#             "AffectedNodes": [
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Account": "rhqTdSsJAaEReRsR27YzddqyGoWTNMhEvC",
#                     "Balance": "217691174",
#                     "Flags": 0,
#                     "OwnerCount": 13,
#                     "Sequence": 71860160
#                   },
#                   "LedgerEntryType": "AccountRoot",
#                   "LedgerIndex": "4F7BC1BE763E253402D0CA5E58E7003D326BEA2FEB5C0FEE228660F795466F6E",
#                   "PreviousFields": {
#                     "Balance": "217687160"
#                   },
#                   "PreviousTxnID": "83B9F180994B9F1EE39924CA72263ED8E7C1F6882AF264F47EB5DDB1C1B68FC4",
#                   "PreviousTxnLgrSeq": 90588709
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Balance": {
#                       "currency": "534F4C4F00000000000000000000000000000000",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "-276.9547187697477"
#                     },
#                     "Flags": 2228224,
#                     "HighLimit": {
#                       "currency": "534F4C4F00000000000000000000000000000000",
#                       "issuer": "rhqTdSsJAaEReRsR27YzddqyGoWTNMhEvC",
#                       "value": "399134226.5095641"
#                     },
#                     "HighNode": "0",
#                     "LowLimit": {
#                       "currency": "534F4C4F00000000000000000000000000000000",
#                       "issuer": "rsoLo2S1kiGeCcn6hCUXVrCpGMWLrRrLZz",
#                       "value": "0"
#                     },
#                     "LowNode": "36a5"
#                   },
#                   "LedgerEntryType": "RippleState",
#                   "LedgerIndex": "9DB660A1BF3B982E5A8F4BE0BD4684FEFEBE575741928E67E4EA1DAEA02CA5A6",
#                   "PreviousFields": {
#                     "Balance": {
#                       "currency": "534F4C4F00000000000000000000000000000000",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "-276.9785628163038"
#                     }
#                   },
#                   "PreviousTxnID": "83B9F180994B9F1EE39924CA72263ED8E7C1F6882AF264F47EB5DDB1C1B68FC4",
#                   "PreviousTxnLgrSeq": 90588709
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Account": "rapido5rxPmP4YkMZZEeXSHqWefxHEkqv6",
#                     "AccountTxnID": "09C6A57F813CDCD15C8365F02FEEA120E3F2BD4717AA816ED1B8B1F74EEC197D",
#                     "Balance": "2705916543",
#                     "Flags": 0,
#                     "OwnerCount": 276,
#                     "Sequence": 18072356
#                   },
#                   "LedgerEntryType": "AccountRoot",
#                   "LedgerIndex": "BFF40FB02870A44349BB5E482CD2A4AA3415C7E72F4D2E9E98129972F26DA9AA",
#                   "PreviousFields": {
#                     "AccountTxnID": "BABF6B1A1783BB107B5D3226AA6010AAF46115D2985D7A9328CE389D75D01BB4",
#                     "Balance": "2705920567",
#                     "Sequence": 18072355
#                   },
#                   "PreviousTxnID": "BABF6B1A1783BB107B5D3226AA6010AAF46115D2985D7A9328CE389D75D01BB4",
#                   "PreviousTxnLgrSeq": 90588710
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Account": "rhqTdSsJAaEReRsR27YzddqyGoWTNMhEvC",
#                     "BookDirectory": "5C8970D155D65DB8FF49B291D7EFFA4A09F9E8A68D9974B25A05FB1434DE9BFC",
#                     "BookNode": "0",
#                     "Flags": 0,
#                     "OwnerNode": "0",
#                     "Sequence": 71860158,
#                     "TakerGets": {
#                       "currency": "534F4C4F00000000000000000000000000000000",
#                       "issuer": "rsoLo2S1kiGeCcn6hCUXVrCpGMWLrRrLZz",
#                       "value": "118.6657369236624"
#                     },
#                     "TakerPays": "19976654"
#                   },
#                   "LedgerEntryType": "Offer",
#                   "LedgerIndex": "C3F4827A24037EDDB48368442567644E8B3B858C217788B5D9117B9799B6E1AB",
#                   "PreviousFields": {
#                     "TakerGets": {
#                       "currency": "534F4C4F00000000000000000000000000000000",
#                       "issuer": "rsoLo2S1kiGeCcn6hCUXVrCpGMWLrRrLZz",
#                       "value": "118.6895809702185"
#                     },
#                     "TakerPays": "19980668"
#                   },
#                   "PreviousTxnID": "83B9F180994B9F1EE39924CA72263ED8E7C1F6882AF264F47EB5DDB1C1B68FC4",
#                   "PreviousTxnLgrSeq": 90588709
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Balance": {
#                       "currency": "534F4C4F00000000000000000000000000000000",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "-0.02384166238988502"
#                     },
#                     "Flags": 2228224,
#                     "HighLimit": {
#                       "currency": "534F4C4F00000000000000000000000000000000",
#                       "issuer": "rapido5rxPmP4YkMZZEeXSHqWefxHEkqv6",
#                       "value": "9999999999999999e80"
#                     },
#                     "HighNode": "19e",
#                     "LowLimit": {
#                       "currency": "534F4C4F00000000000000000000000000000000",
#                       "issuer": "rsoLo2S1kiGeCcn6hCUXVrCpGMWLrRrLZz",
#                       "value": "0"
#                     },
#                     "LowNode": "38a4"
#                   },
#                   "LedgerEntryType": "RippleState",
#                   "LedgerIndex": "E56AB275B511ECDF6E9C9D8BE9404F3FECBE5C841770584036FF8A832AF3F3B9",
#                   "PreviousFields": {
#                     "Balance": {
#                       "currency": "534F4C4F00000000000000000000000000000000",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "0"
#                     }
#                   },
#                   "PreviousTxnID": "7819AC642393456B19230045AE6D08A246976BAC39A4D61DA38C6181D7359753",
#                   "PreviousTxnLgrSeq": 90588709
#                 }
#               }
#             ],
#             "DeliveredAmount": {
#               "currency": "534F4C4F00000000000000000000000000000000",
#               "issuer": "rsoLo2S1kiGeCcn6hCUXVrCpGMWLrRrLZz",
#               "value": "0.02384166238988502"
#             },
#             "TransactionIndex": 37,
#             "TransactionResult": "tesSUCCESS",
#             "delivered_amount": {
#               "currency": "534F4C4F00000000000000000000000000000000",
#               "issuer": "rsoLo2S1kiGeCcn6hCUXVrCpGMWLrRrLZz",
#               "value": "0.02384166238988502"
#             }
#           }
#         },
#         {
#           "Account": "r3PDXzXky6gboMrwurmSCiUyhzdrFyAbfu",
#           "Fee": "12",
#           "Flags": 0,
#           "LastLedgerSequence": 90588728,
#           "LimitAmount": {
#             "currency": "USD",
#             "issuer": "rDLx56UDgChRy3HqwkFSDBpX4hL6sEgmtx",
#             "value": "0.530353"
#           },
#           "Memos": [
#             {
#               "Memo": {
#                 "MemoData": "302E3532393739",
#                 "MemoFormat": "746578742F637376",
#                 "MemoType": "72617465733A6269747374616D703A757364"
#               }
#             },
#             {
#               "Memo": {
#                 "MemoData": "302E3532393635",
#                 "MemoFormat": "746578742F637376",
#                 "MemoType": "72617465733A6B72616B656E3A757364"
#               }
#             },
#             {
#               "Memo": {
#                 "MemoData": "302E3533303631",
#                 "MemoFormat": "746578742F637376",
#                 "MemoType": "72617465733A62697466696E65783A757364"
#               }
#             },
#             {
#               "Memo": {
#                 "MemoData": "302E3532393537",
#                 "MemoFormat": "746578742F637376",
#                 "MemoType": "72617465733A627473653A757364"
#               }
#             },
#             {
#               "Memo": {
#                 "MemoData": "302E3533303532",
#                 "MemoFormat": "746578742F637376",
#                 "MemoType": "72617465733A696E646570656E64656E742D726573657276653A757364"
#               }
#             },
#             {
#               "Memo": {
#                 "MemoData": "302E3533313938",
#                 "MemoFormat": "746578742F637376",
#                 "MemoType": "72617465733A626974686173683A757364"
#               }
#             }
#           ],
#           "Sequence": 90597122,
#           "SigningPubKey": "ED4790E7B26BAC58D2C5B853A47A86F503931A4862395F403C6AE6B646FA27CC25",
#           "TransactionType": "TrustSet",
#           "TxnSignature": "B3857421F1AF9A237EDC99BA6F98222539280A589ED4E35C58D56B7B0FDB6C73828F7748B8B7EF2DF93994B22EF07BD4A4CABEB9B984A8D8447E6DA10C604B01",
#           "hash": "0D72E269569D3BECE2E2014C0DFC1CCECDC01B78052DB8E435E476C1F98FC649",
#           "metaData": {
#             "AffectedNodes": [
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Account": "r3PDXzXky6gboMrwurmSCiUyhzdrFyAbfu",
#                     "Balance": "47607304",
#                     "Flags": 0,
#                     "OwnerCount": 16,
#                     "Sequence": 90597123
#                   },
#                   "LedgerEntryType": "AccountRoot",
#                   "LedgerIndex": "4CA84386D26EDA744A7C5080EC3101931AC2409461F3BB17A3178846B90F8A9C",
#                   "PreviousFields": {
#                     "Balance": "47607316",
#                     "Sequence": 90597122
#                   },
#                   "PreviousTxnID": "E8A82B4F6469D58F75A5B2EDCE1B946A0BB5648EE46B88ED5E7E65360165CCC5",
#                   "PreviousTxnLgrSeq": 90588695
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Balance": {
#                       "currency": "USD",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "0"
#                     },
#                     "Flags": 2162688,
#                     "HighLimit": {
#                       "currency": "USD",
#                       "issuer": "rDLx56UDgChRy3HqwkFSDBpX4hL6sEgmtx",
#                       "value": "0"
#                     },
#                     "HighNode": "0",
#                     "LowLimit": {
#                       "currency": "USD",
#                       "issuer": "r3PDXzXky6gboMrwurmSCiUyhzdrFyAbfu",
#                       "value": "0.530353"
#                     },
#                     "LowNode": "0"
#                   },
#                   "LedgerEntryType": "RippleState",
#                   "LedgerIndex": "F7C8D8CB28F586921D2F5FD747368332D29B8D0B1C5DA3FB2166B4E8D25C55E7",
#                   "PreviousFields": {
#                     "LowLimit": {
#                       "currency": "USD",
#                       "issuer": "r3PDXzXky6gboMrwurmSCiUyhzdrFyAbfu",
#                       "value": "0.530467"
#                     }
#                   },
#                   "PreviousTxnID": "C16140CE3DE35219FF646567AE938276312B9765879B6A2D37014D7F5B8EEC17",
#                   "PreviousTxnLgrSeq": 90588695
#                 }
#               }
#             ],
#             "TransactionIndex": 19,
#             "TransactionResult": "tesSUCCESS"
#           }
#         },
#         {
#           "Account": "rapido5rxPmP4YkMZZEeXSHqWefxHEkqv6",
#           "Fee": "10",
#           "Flags": 655360,
#           "LastLedgerSequence": 90588711,
#           "Sequence": 18072361,
#           "SigningPubKey": "EDE30BA017ED458B9B372295863B042C2BA8F11AD53B4BDFB398E778CB7679146B",
#           "TakerGets": {
#             "currency": "4F70756C656E6365000000000000000000000000",
#             "issuer": "rs5wxrBTSErywDDfPs5NY4Zorrca5QMGVd",
#             "value": "0.03338818424549332"
#           },
#           "TakerPays": {
#             "currency": "BTC",
#             "issuer": "rchGBxcD1A1C2tdxF6papQYZ8kjRKMYcL",
#             "value": "1460260046545446e-28"
#           },
#           "TransactionType": "OfferCreate",
#           "TxnSignature": "CDBDD169D25C4EDE391F71265B752E37D314710BA95E6D256011CFA6D2CB2FD85B645179B633452C46B3B21104980EE6CD58E8B4B3E548585B3E370CFF05B70A",
#           "hash": "0DDDB5FE0EBA1A1DB0B6DCF43A635CE1AF73ADC5E4BBD9A0FEC5BDB7AFE74257",
#           "metaData": {
#             "AffectedNodes": [
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Balance": {
#                       "currency": "4F70756C656E6365000000000000000000000000",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "0"
#                     },
#                     "Flags": 2228224,
#                     "HighLimit": {
#                       "currency": "4F70756C656E6365000000000000000000000000",
#                       "issuer": "rapido5rxPmP4YkMZZEeXSHqWefxHEkqv6",
#                       "value": "9999999999999999e80"
#                     },
#                     "HighNode": "19e",
#                     "LowLimit": {
#                       "currency": "4F70756C656E6365000000000000000000000000",
#                       "issuer": "rs5wxrBTSErywDDfPs5NY4Zorrca5QMGVd",
#                       "value": "0"
#                     },
#                     "LowNode": "12c"
#                   },
#                   "LedgerEntryType": "RippleState",
#                   "LedgerIndex": "365E5416B456A6BE2E2CDC96D0C7E6441244295BEA64F27093D5FD4DED3CAFEE",
#                   "PreviousFields": {
#                     "Balance": {
#                       "currency": "4F70756C656E6365000000000000000000000000",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "-0.01931254666589055"
#                     }
#                   },
#                   "PreviousTxnID": "1F5DCA64E68BB49131E76C3E484AEABAD3907DE420CBC798CE16C37A2FA5C0C6",
#                   "PreviousTxnLgrSeq": 90588710
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Balance": {
#                       "currency": "BTC",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "-8444414742253044e-26"
#                     },
#                     "Flags": 2228224,
#                     "HighLimit": {
#                       "currency": "BTC",
#                       "issuer": "rapido5rxPmP4YkMZZEeXSHqWefxHEkqv6",
#                       "value": "9999999999999999e80"
#                     },
#                     "HighNode": "19c",
#                     "LowLimit": {
#                       "currency": "BTC",
#                       "issuer": "rchGBxcD1A1C2tdxF6papQYZ8kjRKMYcL",
#                       "value": "0"
#                     },
#                     "LowNode": "1362"
#                   },
#                   "LedgerEntryType": "RippleState",
#                   "LedgerIndex": "558C37A3ACFAAB712B31C3D8C63EB2F1273F39158648E202848ED81473D90C72",
#                   "PreviousFields": {
#                     "Balance": {
#                       "currency": "BTC",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "0"
#                     }
#                   },
#                   "PreviousTxnID": "25F7244146A97F942561A82EC7FFC59EE1C871C30EB104A40DED93D63723164A",
#                   "PreviousTxnLgrSeq": 90588709
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Balance": {
#                       "currency": "BTC",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "-0.0001634111298385811"
#                     },
#                     "Flags": 16908288,
#                     "HighLimit": {
#                       "currency": "BTC",
#                       "issuer": "rpnnR73giyArBEDM2B2JPj4VxPu3mo2x85",
#                       "value": "0"
#                     },
#                     "HighNode": "0",
#                     "LowLimit": {
#                       "currency": "BTC",
#                       "issuer": "rchGBxcD1A1C2tdxF6papQYZ8kjRKMYcL",
#                       "value": "0"
#                     },
#                     "LowNode": "1347"
#                   },
#                   "LedgerEntryType": "RippleState",
#                   "LedgerIndex": "5767A050428DA5BE3B957CC49A9106CD11E2C815890778E2222BEF5E58DA21B3",
#                   "PreviousFields": {
#                     "Balance": {
#                       "currency": "BTC",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "-0.0001634112142827285"
#                     }
#                   },
#                   "PreviousTxnID": "49808EA03533EC9C9601323DA636E334F5663EB557D01CE9E619E27451189623",
#                   "PreviousTxnLgrSeq": 90588709
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Balance": {
#                       "currency": "4F70756C656E6365000000000000000000000000",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "37251.09103214289"
#                     },
#                     "Flags": 16842752,
#                     "HighLimit": {
#                       "currency": "4F70756C656E6365000000000000000000000000",
#                       "issuer": "rs5wxrBTSErywDDfPs5NY4Zorrca5QMGVd",
#                       "value": "0"
#                     },
#                     "HighNode": "125",
#                     "LowLimit": {
#                       "currency": "4F70756C656E6365000000000000000000000000",
#                       "issuer": "rpnnR73giyArBEDM2B2JPj4VxPu3mo2x85",
#                       "value": "0"
#                     },
#                     "LowNode": "0"
#                   },
#                   "LedgerEntryType": "RippleState",
#                   "LedgerIndex": "6212ECBA07202DEC5EECA591039EFF02C3587E15ACF58F59F90C944236B198B7",
#                   "PreviousFields": {
#                     "Balance": {
#                       "currency": "4F70756C656E6365000000000000000000000000",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "37251.07171959622"
#                     }
#                   },
#                   "PreviousTxnID": "49808EA03533EC9C9601323DA636E334F5663EB557D01CE9E619E27451189623",
#                   "PreviousTxnLgrSeq": 90588709
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Account": "rapido5rxPmP4YkMZZEeXSHqWefxHEkqv6",
#                     "AccountTxnID": "0DDDB5FE0EBA1A1DB0B6DCF43A635CE1AF73ADC5E4BBD9A0FEC5BDB7AFE74257",
#                     "Balance": "2705920488",
#                     "Flags": 0,
#                     "OwnerCount": 276,
#                     "Sequence": 18072362
#                   },
#                   "LedgerEntryType": "AccountRoot",
#                   "LedgerIndex": "BFF40FB02870A44349BB5E482CD2A4AA3415C7E72F4D2E9E98129972F26DA9AA",
#                   "PreviousFields": {
#                     "AccountTxnID": "1F5DCA64E68BB49131E76C3E484AEABAD3907DE420CBC798CE16C37A2FA5C0C6",
#                     "Balance": "2705920498",
#                     "Sequence": 18072361
#                   },
#                   "PreviousTxnID": "1F5DCA64E68BB49131E76C3E484AEABAD3907DE420CBC798CE16C37A2FA5C0C6",
#                   "PreviousTxnLgrSeq": 90588710
#                 }
#               }
#             ],
#             "TransactionIndex": 43,
#             "TransactionResult": "tesSUCCESS"
#           }
#         },
#         {
#           "Account": "rf4VZ6LYKnPY1uaEiZF8qzD8vrW91vvjbb",
#           "Fee": "10",
#           "Flags": 0,
#           "LastLedgerSequence": 90588728,
#           "Sequence": 82307482,
#           "SigningPubKey": "EDD17BABBBECFEFE3FCC777113E2A3B9F12F3747B92E6E822E04FE0F2EAFDCF83C",
#           "TicketCount": 100,
#           "TransactionType": "TicketCreate",
#           "TxnSignature": "3FA5267FCB420B30AE5E79EB112F0CE9AAAC857075F9EC5BED4F92608AF949B9B1F63A59959CE57C0DA2C68AE846612CFEE268803C7995D5B53B9F870215200A",
#           "hash": "143B10DA504F8A80044B64724D14C9AE50BE71F0710B479B416D3A2A7BDB1456",
#           "metaData": {
#             "AffectedNodes": [
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Account": "rf4VZ6LYKnPY1uaEiZF8qzD8vrW91vvjbb",
#                     "Balance": "32558633",
#                     "Flags": 0,
#                     "OwnerCount": 5,
#                     "Sequence": 82307483,
#                     "TicketCount": 2
#                   },
#                   "LedgerEntryType": "AccountRoot",
#                   "LedgerIndex": "E306A63B590C825C6278CC92A7D29E4030BA9DE4DE748CD9F9891F01B7045943",
#                   "PreviousFields": {
#                     "Balance": "32558643",
#                     "Sequence": 82307482
#                   },
#                   "PreviousTxnID": "88B10D760DA1B4C3B9CC3EC33327F6DBB8513D693FC7A919E378C1F2FAE65B84",
#                   "PreviousTxnLgrSeq": 90588706
#                 }
#               }
#             ],
#             "TransactionIndex": 50,
#             "TransactionResult": "tecINSUFFICIENT_RESERVE"
#           }
#         },
#         {
#           "Account": "rapido5rxPmP4YkMZZEeXSHqWefxHEkqv6",
#           "Fee": "10",
#           "Flags": 655360,
#           "LastLedgerSequence": 90588711,
#           "Sequence": 18072360,
#           "SigningPubKey": "EDE30BA017ED458B9B372295863B042C2BA8F11AD53B4BDFB398E778CB7679146B",
#           "TakerGets": {
#             "currency": "4249547800000000000000000000000000000000",
#             "issuer": "rBitcoiNXev8VoVxV7pwoQx1sSfonVP9i3",
#             "value": "0.0000005856577471144536"
#           },
#           "TakerPays": {
#             "currency": "4F70756C656E6365000000000000000000000000",
#             "issuer": "rs5wxrBTSErywDDfPs5NY4Zorrca5QMGVd",
#             "value": "0.00002782348687124443"
#           },
#           "TransactionType": "OfferCreate",
#           "TxnSignature": "5BDE09A527EF6F7C752EA994E10CBB32BD0B724C6752B4E62D53EDDBC5AA7CC2E7872D26C44945E6EAD9BF7E9F3BF15E1D31E802945004B29D4D7C8398052C0C",
#           "hash": "1F5DCA64E68BB49131E76C3E484AEABAD3907DE420CBC798CE16C37A2FA5C0C6",
#           "metaData": {
#             "AffectedNodes": [
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Balance": {
#                       "currency": "4F70756C656E6365000000000000000000000000",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "-9935.963139817728"
#                     },
#                     "Flags": 16908288,
#                     "HighLimit": {
#                       "currency": "4F70756C656E6365000000000000000000000000",
#                       "issuer": "raPCXuvRxb8BATir7fQEcSMtV772JvxLdM",
#                       "value": "0"
#                     },
#                     "HighNode": "0",
#                     "LowLimit": {
#                       "currency": "4F70756C656E6365000000000000000000000000",
#                       "issuer": "rs5wxrBTSErywDDfPs5NY4Zorrca5QMGVd",
#                       "value": "0"
#                     },
#                     "LowNode": "12b"
#                   },
#                   "LedgerEntryType": "RippleState",
#                   "LedgerIndex": "10A9D769D62E32FCC9A123524F899BD0EA429ACC096C4963F475C267DBA34925",
#                   "PreviousFields": {
#                     "Balance": {
#                       "currency": "4F70756C656E6365000000000000000000000000",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "-9935.982452364394"
#                     }
#                   },
#                   "PreviousTxnID": "E3A1233F054996F9AE0FB92D13387B809C63F72A0BD0405D87C56742ADCF42DC",
#                   "PreviousTxnLgrSeq": 90588709
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Balance": {
#                       "currency": "4249547800000000000000000000000000000000",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "0.2091408216398598"
#                     },
#                     "Flags": 16842752,
#                     "HighLimit": {
#                       "currency": "4249547800000000000000000000000000000000",
#                       "issuer": "rBitcoiNXev8VoVxV7pwoQx1sSfonVP9i3",
#                       "value": "0"
#                     },
#                     "HighNode": "e1",
#                     "LowLimit": {
#                       "currency": "4249547800000000000000000000000000000000",
#                       "issuer": "raPCXuvRxb8BATir7fQEcSMtV772JvxLdM",
#                       "value": "0"
#                     },
#                     "LowNode": "0"
#                   },
#                   "LedgerEntryType": "RippleState",
#                   "LedgerIndex": "32EA677778A67C292AA49E65917A998518030A24173525415FEE3131ED62FA3B",
#                   "PreviousFields": {
#                     "Balance": {
#                       "currency": "4249547800000000000000000000000000000000",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "0.2091404150284156"
#                     }
#                   },
#                   "PreviousTxnID": "E3A1233F054996F9AE0FB92D13387B809C63F72A0BD0405D87C56742ADCF42DC",
#                   "PreviousTxnLgrSeq": 90588709
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Balance": {
#                       "currency": "4F70756C656E6365000000000000000000000000",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "-0.01931254666589055"
#                     },
#                     "Flags": 2228224,
#                     "HighLimit": {
#                       "currency": "4F70756C656E6365000000000000000000000000",
#                       "issuer": "rapido5rxPmP4YkMZZEeXSHqWefxHEkqv6",
#                       "value": "9999999999999999e80"
#                     },
#                     "HighNode": "19e",
#                     "LowLimit": {
#                       "currency": "4F70756C656E6365000000000000000000000000",
#                       "issuer": "rs5wxrBTSErywDDfPs5NY4Zorrca5QMGVd",
#                       "value": "0"
#                     },
#                     "LowNode": "12c"
#                   },
#                   "LedgerEntryType": "RippleState",
#                   "LedgerIndex": "365E5416B456A6BE2E2CDC96D0C7E6441244295BEA64F27093D5FD4DED3CAFEE",
#                   "PreviousFields": {
#                     "Balance": {
#                       "currency": "4F70756C656E6365000000000000000000000000",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "0"
#                     }
#                   },
#                   "PreviousTxnID": "49808EA03533EC9C9601323DA636E334F5663EB557D01CE9E619E27451189623",
#                   "PreviousTxnLgrSeq": 90588709
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Account": "rapido5rxPmP4YkMZZEeXSHqWefxHEkqv6",
#                     "AccountTxnID": "1F5DCA64E68BB49131E76C3E484AEABAD3907DE420CBC798CE16C37A2FA5C0C6",
#                     "Balance": "2705920498",
#                     "Flags": 0,
#                     "OwnerCount": 276,
#                     "Sequence": 18072361
#                   },
#                   "LedgerEntryType": "AccountRoot",
#                   "LedgerIndex": "BFF40FB02870A44349BB5E482CD2A4AA3415C7E72F4D2E9E98129972F26DA9AA",
#                   "PreviousFields": {
#                     "AccountTxnID": "2F8D23448FC6F820EC2F9AEA7EBE72C6110E50248E11153C0EE8F8E706BBD6CF",
#                     "Balance": "2705920508",
#                     "Sequence": 18072360
#                   },
#                   "PreviousTxnID": "2F8D23448FC6F820EC2F9AEA7EBE72C6110E50248E11153C0EE8F8E706BBD6CF",
#                   "PreviousTxnLgrSeq": 90588710
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Balance": {
#                       "currency": "4249547800000000000000000000000000000000",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "0"
#                     },
#                     "Flags": 1114112,
#                     "HighLimit": {
#                       "currency": "4249547800000000000000000000000000000000",
#                       "issuer": "rBitcoiNXev8VoVxV7pwoQx1sSfonVP9i3",
#                       "value": "0"
#                     },
#                     "HighNode": "e1",
#                     "LowLimit": {
#                       "currency": "4249547800000000000000000000000000000000",
#                       "issuer": "rapido5rxPmP4YkMZZEeXSHqWefxHEkqv6",
#                       "value": "9999999999999999e80"
#                     },
#                     "LowNode": "19e"
#                   },
#                   "LedgerEntryType": "RippleState",
#                   "LedgerIndex": "D63A73BFE673289DA86434524C38EBA61561FC4C7614601A6173E85C92A0AC07",
#                   "PreviousFields": {
#                     "Balance": {
#                       "currency": "4249547800000000000000000000000000000000",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "0.0000004066114441703296"
#                     }
#                   },
#                   "PreviousTxnID": "2F8D23448FC6F820EC2F9AEA7EBE72C6110E50248E11153C0EE8F8E706BBD6CF",
#                   "PreviousTxnLgrSeq": 90588710
#                 }
#               }
#             ],
#             "TransactionIndex": 42,
#             "TransactionResult": "tesSUCCESS"
#           }
#         },
#         {
#           "Account": "rUTEn2jLLv4ESmrUqQmhZfEfDN3LorhgvZ",
#           "Fee": "15",
#           "Flags": 0,
#           "LastLedgerSequence": 90588712,
#           "OfferSequence": 29418789,
#           "Sequence": 29418792,
#           "SigningPubKey": "021C987881039AD42AEC336FB8460F1B1F4DDF0839CAF3EAB1AF69DDF8012C30A3",
#           "TakerGets": "6838952554",
#           "TakerPays": {
#             "currency": "CNY",
#             "issuer": "rJ1adrpGS3xsnQMb9Cw54tWJVFPuSdZHK",
#             "value": "29869.39884184263"
#           },
#           "TransactionType": "OfferCreate",
#           "TxnSignature": "3044022053F5D487B60A37953A4285DF106BA5805DFC2126074950368BB442D2A38CF66F0220024636E7803DC3729CCED3F5C6E46E6766898D61315EC03345B1E6F783EF54EB",
#           "hash": "2B85D5B52F2B73EE2C5AB003D966967DC710C6F539CFE4684DC84AA651F30861",
#           "metaData": {
#             "AffectedNodes": [
#               {
#                 "DeletedNode": {
#                   "FinalFields": {
#                     "Account": "rUTEn2jLLv4ESmrUqQmhZfEfDN3LorhgvZ",
#                     "BookDirectory": "623C4C4AD65873DA787AC85A0A1385FE6233B6DE100799474F11FCF1C9667E49",
#                     "BookNode": "0",
#                     "Flags": 0,
#                     "OwnerNode": "0",
#                     "PreviousTxnID": "25A1AA144A798A100BD397BC8191EA9604259310B55B8E01D0C215D71F53C919",
#                     "PreviousTxnLgrSeq": 90588708,
#                     "Sequence": 29418789,
#                     "TakerGets": "11428815748",
#                     "TakerPays": {
#                       "currency": "CNY",
#                       "issuer": "rJ1adrpGS3xsnQMb9Cw54tWJVFPuSdZHK",
#                       "value": "57866.26561096142"
#                     }
#                   },
#                   "LedgerEntryType": "Offer",
#                   "LedgerIndex": "125D37BB79A78A8C0C63182966C959C4CC8B3E40753D0F9D0AAA44C046F8C684"
#                 }
#               },
#               {
#                 "CreatedNode": {
#                   "LedgerEntryType": "DirectoryNode",
#                   "LedgerIndex": "623C4C4AD65873DA787AC85A0A1385FE6233B6DE100799474F0F8441264747CC",
#                   "NewFields": {
#                     "ExchangeRate": "4f0f8441264747cc",
#                     "RootIndex": "623C4C4AD65873DA787AC85A0A1385FE6233B6DE100799474F0F8441264747CC",
#                     "TakerPaysCurrency": "000000000000000000000000434E590000000000",
#                     "TakerPaysIssuer": "0360E3E0751BD9A566CD03FA6CAFC78118B82BA0"
#                   }
#                 }
#               },
#               {
#                 "DeletedNode": {
#                   "FinalFields": {
#                     "ExchangeRate": "4f11fcf1c9667e49",
#                     "Flags": 0,
#                     "RootIndex": "623C4C4AD65873DA787AC85A0A1385FE6233B6DE100799474F11FCF1C9667E49",
#                     "TakerGetsCurrency": "0000000000000000000000000000000000000000",
#                     "TakerGetsIssuer": "0000000000000000000000000000000000000000",
#                     "TakerPaysCurrency": "000000000000000000000000434E590000000000",
#                     "TakerPaysIssuer": "0360E3E0751BD9A566CD03FA6CAFC78118B82BA0"
#                   },
#                   "LedgerEntryType": "DirectoryNode",
#                   "LedgerIndex": "623C4C4AD65873DA787AC85A0A1385FE6233B6DE100799474F11FCF1C9667E49"
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Account": "rUTEn2jLLv4ESmrUqQmhZfEfDN3LorhgvZ",
#                     "Balance": "5146767727",
#                     "Flags": 0,
#                     "OwnerCount": 5,
#                     "Sequence": 29418793
#                   },
#                   "LedgerEntryType": "AccountRoot",
#                   "LedgerIndex": "7645DE0D353FF9ECB95EE6D8A5C51A666BBBA29860C30B45C529957871E586C1",
#                   "PreviousFields": {
#                     "Balance": "5146767742",
#                     "Sequence": 29418792
#                   },
#                   "PreviousTxnID": "5744F0654CDCA5D135CE7B0C1FB1B029C5F197451B588CEF606BEA454C921460",
#                   "PreviousTxnLgrSeq": 90588708
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Flags": 0,
#                     "IndexNext": "0",
#                     "IndexPrevious": "0",
#                     "Owner": "rUTEn2jLLv4ESmrUqQmhZfEfDN3LorhgvZ",
#                     "RootIndex": "C1806EB01C8FA2A0E78311B4D24FBFD21003E89934435DB975F40610FE0D1FAC"
#                   },
#                   "LedgerEntryType": "DirectoryNode",
#                   "LedgerIndex": "C1806EB01C8FA2A0E78311B4D24FBFD21003E89934435DB975F40610FE0D1FAC"
#                 }
#               },
#               {
#                 "CreatedNode": {
#                   "LedgerEntryType": "Offer",
#                   "LedgerIndex": "F38BDC75374553DC295A37A233033F47A43802DA6B138D39450E83EC6633392D",
#                   "NewFields": {
#                     "Account": "rUTEn2jLLv4ESmrUqQmhZfEfDN3LorhgvZ",
#                     "BookDirectory": "623C4C4AD65873DA787AC85A0A1385FE6233B6DE100799474F0F8441264747CC",
#                     "Sequence": 29418792,
#                     "TakerGets": "6838952554",
#                     "TakerPays": {
#                       "currency": "CNY",
#                       "issuer": "rJ1adrpGS3xsnQMb9Cw54tWJVFPuSdZHK",
#                       "value": "29869.39884184263"
#                     }
#                   }
#                 }
#               }
#             ],
#             "TransactionIndex": 4,
#             "TransactionResult": "tesSUCCESS"
#           }
#         },
#         {
#           "Account": "rBTwLga3i2gz3doX6Gva3MgEV8ZCD8jjah",
#           "Fee": "20",
#           "Flags": 0,
#           "LastLedgerSequence": 90588712,
#           "OfferSequence": 151056156,
#           "Sequence": 151056166,
#           "SigningPubKey": "0253C1DFDCF898FE85F16B71CCE80A5739F7223D54CC9EBA4749616593470298C5",
#           "TakerGets": "33803000000",
#           "TakerPays": {
#             "currency": "5553444300000000000000000000000000000000",
#             "issuer": "rcEGREd8NmkKRE8GE424sksyt1tJVFZwu",
#             "value": "18968.21542"
#           },
#           "TransactionType": "OfferCreate",
#           "TxnSignature": "3045022100D9420E765A7D9D8F7AC7654D907C05330483984DF3AD76BCAD42C43E0500676A022022821248E9675169ABE2C97875467EEACDF8452B02B2FF4B19878355CDE25B6B",
#           "hash": "2BA440FE503FF856F0233BBFA148E973F5B3A39C1435C6AB3F09F2E31071770F",
#           "metaData": {
#             "AffectedNodes": [
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Flags": 0,
#                     "IndexNext": "0",
#                     "IndexPrevious": "0",
#                     "Owner": "rBTwLga3i2gz3doX6Gva3MgEV8ZCD8jjah",
#                     "RootIndex": "0A2600D85F8309FE7F75A490C19613F1CE0C37483B856DB69B8140154C2335F3"
#                   },
#                   "LedgerEntryType": "DirectoryNode",
#                   "LedgerIndex": "0A2600D85F8309FE7F75A490C19613F1CE0C37483B856DB69B8140154C2335F3"
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Account": "rBTwLga3i2gz3doX6Gva3MgEV8ZCD8jjah",
#                     "Balance": "33903857061",
#                     "Flags": 0,
#                     "OwnerCount": 15,
#                     "Sequence": 151056167
#                   },
#                   "LedgerEntryType": "AccountRoot",
#                   "LedgerIndex": "1ED8DDFD80F275CB1CE7F18BB9D906655DE8029805D8B95FB9020B30425821EB",
#                   "PreviousFields": {
#                     "Balance": "33903857081",
#                     "Sequence": 151056166
#                   },
#                   "PreviousTxnID": "E2FE7BAA1FE75FB1E60DD5F356C2A5B053CA08C1F9E6EC531E7231BF4DB0073C",
#                   "PreviousTxnLgrSeq": 90588710
#                 }
#               },
#               {
#                 "CreatedNode": {
#                   "LedgerEntryType": "DirectoryNode",
#                   "LedgerIndex": "33DFFDF31565C801C27B84E5A0202D944687663C0BDCD0144E13EF89DFB15000",
#                   "NewFields": {
#                     "ExchangeRate": "4e13ef89dfb15000",
#                     "RootIndex": "33DFFDF31565C801C27B84E5A0202D944687663C0BDCD0144E13EF89DFB15000",
#                     "TakerPaysCurrency": "5553444300000000000000000000000000000000",
#                     "TakerPaysIssuer": "06AA7798F7A8FA6914CC1E82C556E5B0A0CCB9E3"
#                   }
#                 }
#               },
#               {
#                 "DeletedNode": {
#                   "FinalFields": {
#                     "ExchangeRate": "4e13efa128283800",
#                     "Flags": 0,
#                     "RootIndex": "33DFFDF31565C801C27B84E5A0202D944687663C0BDCD0144E13EFA128283800",
#                     "TakerGetsCurrency": "0000000000000000000000000000000000000000",
#                     "TakerGetsIssuer": "0000000000000000000000000000000000000000",
#                     "TakerPaysCurrency": "5553444300000000000000000000000000000000",
#                     "TakerPaysIssuer": "06AA7798F7A8FA6914CC1E82C556E5B0A0CCB9E3"
#                   },
#                   "LedgerEntryType": "DirectoryNode",
#                   "LedgerIndex": "33DFFDF31565C801C27B84E5A0202D944687663C0BDCD0144E13EFA128283800"
#                 }
#               },
#               {
#                 "CreatedNode": {
#                   "LedgerEntryType": "Offer",
#                   "LedgerIndex": "9CF466298376812667A2C021356EB0923CB45D8139DB0FC9FB69125B8F38E362",
#                   "NewFields": {
#                     "Account": "rBTwLga3i2gz3doX6Gva3MgEV8ZCD8jjah",
#                     "BookDirectory": "33DFFDF31565C801C27B84E5A0202D944687663C0BDCD0144E13EF89DFB15000",
#                     "Sequence": 151056166,
#                     "TakerGets": "33803000000",
#                     "TakerPays": {
#                       "currency": "5553444300000000000000000000000000000000",
#                       "issuer": "rcEGREd8NmkKRE8GE424sksyt1tJVFZwu",
#                       "value": "18968.21542"
#                     }
#                   }
#                 }
#               },
#               {
#                 "DeletedNode": {
#                   "FinalFields": {
#                     "Account": "rBTwLga3i2gz3doX6Gva3MgEV8ZCD8jjah",
#                     "BookDirectory": "33DFFDF31565C801C27B84E5A0202D944687663C0BDCD0144E13EFA128283800",
#                     "BookNode": "0",
#                     "Flags": 0,
#                     "OwnerNode": "0",
#                     "PreviousTxnID": "47C2DD9DA9AC2A8C2B1DFEE5B647FF8EC6F2772C0BCF7C01389BA073ACC3428D",
#                     "PreviousTxnLgrSeq": 90588708,
#                     "Sequence": 151056156,
#                     "TakerGets": "33803000000",
#                     "TakerPays": {
#                       "currency": "5553444300000000000000000000000000000000",
#                       "issuer": "rcEGREd8NmkKRE8GE424sksyt1tJVFZwu",
#                       "value": "18968.55345"
#                     }
#                   },
#                   "LedgerEntryType": "Offer",
#                   "LedgerIndex": "C3F1A86EED4E319C8AD9FEEDC356C969B8AA8DC067C10CE8A01B0B6E5947E1CB"
#                 }
#               }
#             ],
#             "TransactionIndex": 15,
#             "TransactionResult": "tesSUCCESS"
#           }
#         },
#         {
#           "Account": "rapido5rxPmP4YkMZZEeXSHqWefxHEkqv6",
#           "Fee": "10",
#           "Flags": 655360,
#           "LastLedgerSequence": 90588711,
#           "Sequence": 18072359,
#           "SigningPubKey": "EDE30BA017ED458B9B372295863B042C2BA8F11AD53B4BDFB398E778CB7679146B",
#           "TakerGets": {
#             "currency": "OVO",
#             "issuer": "r3jQzqfGVagsWNbSxMJpQV8VK7jHHmdv5j",
#             "value": "1.104653295409846"
#           },
#           "TakerPays": {
#             "currency": "4249547800000000000000000000000000000000",
#             "issuer": "rBitcoiNXev8VoVxV7pwoQx1sSfonVP9i3",
#             "value": "0.0000000004880481225953781"
#           },
#           "TransactionType": "OfferCreate",
#           "TxnSignature": "ACEA44F1A938CE8903D533C569983386B48EB0B36C9F8B25F2F7704E8A66C0DFF4163B37D218569FAC897B9FC6EA3EDD40C8FD7AE2FD4C3AEB1A862B6E813F04",
#           "hash": "2F8D23448FC6F820EC2F9AEA7EBE72C6110E50248E11153C0EE8F8E706BBD6CF",
#           "metaData": {
#             "AffectedNodes": [
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Balance": {
#                       "currency": "OVO",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "0"
#                     },
#                     "Flags": 1114112,
#                     "HighLimit": {
#                       "currency": "OVO",
#                       "issuer": "r3jQzqfGVagsWNbSxMJpQV8VK7jHHmdv5j",
#                       "value": "0"
#                     },
#                     "HighNode": "33f",
#                     "LowLimit": {
#                       "currency": "OVO",
#                       "issuer": "rapido5rxPmP4YkMZZEeXSHqWefxHEkqv6",
#                       "value": "9999999999999999e80"
#                     },
#                     "LowNode": "19d"
#                   },
#                   "LedgerEntryType": "RippleState",
#                   "LedgerIndex": "8EB8D4D2D6968FF99D8DD3993C7E77BE09D0F25951E7FA67077494C366602650",
#                   "PreviousFields": {
#                     "Balance": {
# ...
#                   "LedgerIndex": "EA95E21A9E9CF4498DC4650E56F02845DFA732C4E04BAF876E9D859885CA6C67",
#                   "PreviousFields": {
#                     "Balance": {
#                       "currency": "4249547800000000000000000000000000000000",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "-0.05367731924274013"
#                     }
#                   },
#                   "PreviousTxnID": "2F8D23448FC6F820EC2F9AEA7EBE72C6110E50248E11153C0EE8F8E706BBD6CF",
#                   "PreviousTxnLgrSeq": 90588710
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Balance": {
#                       "currency": "OVO",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "-121479.5582686093"
#                     },
#                     "Flags": 16908288,
#                     "HighLimit": {
#                       "currency": "OVO",
#                       "issuer": "rNQyPaG7ehVDnTUbjQKy8sFcMBLkH11nP6",
#                       "value": "0"
#                     },
#                     "HighNode": "0",
#                     "LowLimit": {
#                       "currency": "OVO",
#                       "issuer": "r3jQzqfGVagsWNbSxMJpQV8VK7jHHmdv5j",
#                       "value": "0"
#                     },
#                     "LowNode": "343"
#                   },
#                   "LedgerEntryType": "RippleState",
#                   "LedgerIndex": "EC5C234C9470780D98D8E64629317F5011AAF48FE2D282739B73FFF6B14829FF",
#                   "PreviousFields": {
#                     "Balance": {
#                       "currency": "OVO",
#                       "issuer": "rrrrrrrrrrrrrrrrrrrrBZbvji",
#                       "value": "-121492.5493755432"
#                     }
#                   },
#                   "PreviousTxnID": "2F8D23448FC6F820EC2F9AEA7EBE72C6110E50248E11153C0EE8F8E706BBD6CF",
#                   "PreviousTxnLgrSeq": 90588710
#                 }
#               }
#             ],
#             "TransactionIndex": 47,
#             "TransactionResult": "tesSUCCESS"
#           }
#         },
#         {
#           "Account": "rBTwLga3i2gz3doX6Gva3MgEV8ZCD8jjah",
#           "Fee": "20",
#           "Flags": 0,
#           "LastLedgerSequence": 90588712,
#           "OfferSequence": 151056153,
#           "Sequence": 151056163,
#           "SigningPubKey": "0253C1DFDCF898FE85F16B71CCE80A5739F7223D54CC9EBA4749616593470298C5",
#           "TakerGets": {
#             "currency": "EUR",
#             "issuer": "rhub8VRN55s94qWKDv6jmDy1pUykJzF3wq",
#             "value": "95139.77380000001"
#           },
#           "TakerPays": "200000000000",
#           "TransactionType": "OfferCreate",
#           "TxnSignature": "3045022100ED9A9F62EC6755DE4775DE61877F7D9C34570D96DD4D8808559C14FC2B5757AB0220205A83C50F8ED721C9A9426F601603D905FA01F1B4F353305157E4485C0134F5",
#           "hash": "F8A803E919FC24CC4259955FF2AA066401FB4D5F562EF9DE684ABA21DBC9EF5B",
#           "metaData": {
#             "AffectedNodes": [
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Flags": 0,
#                     "IndexNext": "0",
#                     "IndexPrevious": "0",
#                     "Owner": "rBTwLga3i2gz3doX6Gva3MgEV8ZCD8jjah",
#                     "RootIndex": "0A2600D85F8309FE7F75A490C19613F1CE0C37483B856DB69B8140154C2335F3"
#                   },
#                   "LedgerEntryType": "DirectoryNode",
#                   "LedgerIndex": "0A2600D85F8309FE7F75A490C19613F1CE0C37483B856DB69B8140154C2335F3"
#                 }
#               },
#               {
#                 "DeletedNode": {
#                   "FinalFields": {
#                     "Account": "rBTwLga3i2gz3doX6Gva3MgEV8ZCD8jjah",
#                     "BookDirectory": "CA462483C85A90DB76D8903681442394D8A5E2D0FFAC259C5B0777E810130FD1",
#                     "BookNode": "0",
#                     "Flags": 0,
#                     "OwnerNode": "0",
#                     "PreviousTxnID": "B308FEF43EF555BE5CA961117903C9C8BD0D5A71B7D6B6BDE6F9E8B52EFB77F6",
#                     "PreviousTxnLgrSeq": 90588708,
#                     "Sequence": 151056153,
#                     "TakerGets": {
#                       "currency": "EUR",
#                       "issuer": "rhub8VRN55s94qWKDv6jmDy1pUykJzF3wq",
#                       "value": "95140.0818"
#                     },
#                     "TakerPays": "200000000000"
#                   },
#                   "LedgerEntryType": "Offer",
#                   "LedgerIndex": "1B2FE8D16FB694D6DEC6E4A7E489F715B8BBBDE9E8C60202E9EA8A75F3A96377"
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Account": "rBTwLga3i2gz3doX6Gva3MgEV8ZCD8jjah",
#                     "Balance": "33903857121",
#                     "Flags": 0,
#                     "OwnerCount": 15,
#                     "Sequence": 151056164
#                   },
#                   "LedgerEntryType": "AccountRoot",
#                   "LedgerIndex": "1ED8DDFD80F275CB1CE7F18BB9D906655DE8029805D8B95FB9020B30425821EB",
#                   "PreviousFields": {
#                     "Balance": "33903857141",
#                     "Sequence": 151056163
#                   },
#                   "PreviousTxnID": "AC6A648A4E0F7C7928D2AB05D7766F2C9886CB3967250E2DD5742A2EA780D9B0",
#                   "PreviousTxnLgrSeq": 90588709
#                 }
#               },
#               {
#                 "CreatedNode": {
#                   "LedgerEntryType": "Offer",
#                   "LedgerIndex": "AC67F60F97A024CC7EDF91268E3B8923A500AF3AEF5A235C0D3F66586768C2BC",
#                   "NewFields": {
#                     "Account": "rBTwLga3i2gz3doX6Gva3MgEV8ZCD8jjah",
#                     "BookDirectory": "CA462483C85A90DB76D8903681442394D8A5E2D0FFAC259C5B0777E9A5B59083",
#                     "Sequence": 151056163,
#                     "TakerGets": {
#                       "currency": "EUR",
#                       "issuer": "rhub8VRN55s94qWKDv6jmDy1pUykJzF3wq",
#                       "value": "95139.77380000001"
#                     },
#                     "TakerPays": "200000000000"
#                   }
#                 }
#               },
#               {
#                 "DeletedNode": {
#                   "FinalFields": {
#                     "ExchangeRate": "5b0777e810130fd1",
#                     "Flags": 0,
#                     "RootIndex": "CA462483C85A90DB76D8903681442394D8A5E2D0FFAC259C5B0777E810130FD1",
#                     "TakerGetsCurrency": "0000000000000000000000004555520000000000",
#                     "TakerGetsIssuer": "2ADB0B3959D60A6E6991F729E1918B7163925230",
#                     "TakerPaysCurrency": "0000000000000000000000000000000000000000",
#                     "TakerPaysIssuer": "0000000000000000000000000000000000000000"
#                   },
#                   "LedgerEntryType": "DirectoryNode",
#                   "LedgerIndex": "CA462483C85A90DB76D8903681442394D8A5E2D0FFAC259C5B0777E810130FD1"
#                 }
#               },
#               {
#                 "CreatedNode": {
#                   "LedgerEntryType": "DirectoryNode",
#                   "LedgerIndex": "CA462483C85A90DB76D8903681442394D8A5E2D0FFAC259C5B0777E9A5B59083",
#                   "NewFields": {
#                     "ExchangeRate": "5b0777e9a5b59083",
#                     "RootIndex": "CA462483C85A90DB76D8903681442394D8A5E2D0FFAC259C5B0777E9A5B59083",
#                     "TakerGetsCurrency": "0000000000000000000000004555520000000000",
#                     "TakerGetsIssuer": "2ADB0B3959D60A6E6991F729E1918B7163925230"
#                   }
#                 }
#               }
#             ],
#             "TransactionIndex": 12,
#             "TransactionResult": "tesSUCCESS"
#           }
#         },
#         {
#           "Account": "rBTwLga3i2gz3doX6Gva3MgEV8ZCD8jjah",
#           "Fee": "20",
#           "Flags": 0,
#           "LastLedgerSequence": 90588712,
#           "OfferSequence": 151056158,
#           "Sequence": 151056168,
#           "SigningPubKey": "0253C1DFDCF898FE85F16B71CCE80A5739F7223D54CC9EBA4749616593470298C5",
#           "TakerGets": "33803000000",
#           "TakerPays": {
#             "currency": "5553445400000000000000000000000000000000",
#             "issuer": "rcvxE9PS9YBwxtGg1qNeewV6ZB3wGubZq",
#             "value": "18404.579228959"
#           },
#           "TransactionType": "OfferCreate",
#           "TxnSignature": "304502210084C7747E766D4D2C908806ADAF304B392B5242AD369C43C2407BC879D9A0302E02201705997140B6599E9D29A1CEA78C6E653BEAE1CB3A4ED4AFD10E60C5114B60B3",
#           "hash": "FEA63894B7F2B4ABE3AE801178473329540E1DD088C3C840AFB5EB92E70D5651",
#           "metaData": {
#             "AffectedNodes": [
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Flags": 0,
#                     "IndexNext": "0",
#                     "IndexPrevious": "0",
#                     "Owner": "rBTwLga3i2gz3doX6Gva3MgEV8ZCD8jjah",
#                     "RootIndex": "0A2600D85F8309FE7F75A490C19613F1CE0C37483B856DB69B8140154C2335F3"
#                   },
#                   "LedgerEntryType": "DirectoryNode",
#                   "LedgerIndex": "0A2600D85F8309FE7F75A490C19613F1CE0C37483B856DB69B8140154C2335F3"
#                 }
#               },
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Account": "rBTwLga3i2gz3doX6Gva3MgEV8ZCD8jjah",
#                     "Balance": "33903857021",
#                     "Flags": 0,
#                     "OwnerCount": 15,
#                     "Sequence": 151056169
#                   },
#                   "LedgerEntryType": "AccountRoot",
#                   "LedgerIndex": "1ED8DDFD80F275CB1CE7F18BB9D906655DE8029805D8B95FB9020B30425821EB",
#                   "PreviousFields": {
#                     "Balance": "33903857041",
#                     "Sequence": 151056168
#                   },
#                   "PreviousTxnID": "B0ACFA57BCFDD10AB30F362AC9A3ED7C85D2E10B81D90E02B5B8EAEA265A961C",
#                   "PreviousTxnLgrSeq": 90588710
#                 }
#               },
#               {
#                 "CreatedNode": {
#                   "LedgerEntryType": "DirectoryNode",
#                   "LedgerIndex": "2410509CE58C2F04403737A3FD84B17D66C423554EEF919D4E1357E3599A9C80",
#                   "NewFields": {
#                     "ExchangeRate": "4e1357e3599a9c80",
#                     "RootIndex": "2410509CE58C2F04403737A3FD84B17D66C423554EEF919D4E1357E3599A9C80",
#                     "TakerPaysCurrency": "5553445400000000000000000000000000000000",
#                     "TakerPaysIssuer": "06CB988E900D81BAE9217E6FE6B60CD2DDA12767"
#                   }
#                 }
#               },
#               {
#                 "DeletedNode": {
#                   "FinalFields": {
#                     "ExchangeRate": "4e1357e8cc5a4680",
#                     "Flags": 0,
#                     "RootIndex": "2410509CE58C2F04403737A3FD84B17D66C423554EEF919D4E1357E8CC5A4680",
#                     "TakerGetsCurrency": "0000000000000000000000000000000000000000",
#                     "TakerGetsIssuer": "0000000000000000000000000000000000000000",
#                     "TakerPaysCurrency": "5553445400000000000000000000000000000000",
#                     "TakerPaysIssuer": "06CB988E900D81BAE9217E6FE6B60CD2DDA12767"
#                   },
#                   "LedgerEntryType": "DirectoryNode",
#                   "LedgerIndex": "2410509CE58C2F04403737A3FD84B17D66C423554EEF919D4E1357E8CC5A4680"
#                 }
#               },
#               {
#                 "DeletedNode": {
#                   "FinalFields": {
#                     "Account": "rBTwLga3i2gz3doX6Gva3MgEV8ZCD8jjah",
#                     "BookDirectory": "2410509CE58C2F04403737A3FD84B17D66C423554EEF919D4E1357E8CC5A4680",
#                     "BookNode": "0",
#                     "Flags": 0,
#                     "OwnerNode": "0",
#                     "PreviousTxnID": "07B508D8DABC687869F3AF8C64705AB6AFF8E2408FD5C55A7A17E8B180F10C09",
#                     "PreviousTxnLgrSeq": 90588708,
#                     "Sequence": 151056158,
#                     "TakerGets": "33803000000",
#                     "TakerPays": {
#                       "currency": "5553445400000000000000000000000000000000",
#                       "issuer": "rcvxE9PS9YBwxtGg1qNeewV6ZB3wGubZq",
#                       "value": "18404.658327979"
#                     }
#                   },
#                   "LedgerEntryType": "Offer",
#                   "LedgerIndex": "DB464CED6BEEA4D247DBA3F64B2733AB8F251EEC89F08B35E21B3BB09AF33C07"
#                 }
#               },
#               {
#                 "CreatedNode": {
#                   "LedgerEntryType": "Offer",
#                   "LedgerIndex": "E3D1939422CCB6EC8A8B58ECFC2B1DEA4C6F7A8474EBF7D75A1406160F75D0CD",
#                   "NewFields": {
#                     "Account": "rBTwLga3i2gz3doX6Gva3MgEV8ZCD8jjah",
#                     "BookDirectory": "2410509CE58C2F04403737A3FD84B17D66C423554EEF919D4E1357E3599A9C80",
#                     "Sequence": 151056168,
#                     "TakerGets": "33803000000",
#                     "TakerPays": {
#                       "currency": "5553445400000000000000000000000000000000",
#                       "issuer": "rcvxE9PS9YBwxtGg1qNeewV6ZB3wGubZq",
#                       "value": "18404.579228959"
#                     }
#                   }
#                 }
#               }
#             ],
#             "TransactionIndex": 17,
#             "TransactionResult": "tesSUCCESS"
#           }
#         },
#         {
#           "Account": "r3PDXzXky6gboMrwurmSCiUyhzdrFyAbfu",
#           "Fee": "12",
#           "Flags": 0,
#           "LastLedgerSequence": 90588729,
#           "LimitAmount": {
#             "currency": "IDR",
#             "issuer": "rDLx56UDgChRy3HqwkFSDBpX4hL6sEgmtx",
#             "value": "8056.5"
#           },
#           "Memos": [
#             {
#               "Memo": {
#                 "MemoData": "37393030",
#                 "MemoFormat": "746578742F637376",
#                 "MemoType": "72617465733A75706269743A696472"
#               }
#             },
#             {
#               "Memo": {
#                 "MemoData": "38323133",
#                 "MemoFormat": "746578742F637376",
#                 "MemoType": "72617465733A696E646F6461783A696472"
#               }
#             }
#           ],
#           "Sequence": 90597135,
#           "SigningPubKey": "ED4790E7B26BAC58D2C5B853A47A86F503931A4862395F403C6AE6B646FA27CC25",
#           "TransactionType": "TrustSet",
#           "TxnSignature": "946E612EF32024856327D3713B4C9CF12B5006C13EE6CC689F78682AD2197138D2EE613205F3D7859A5352A5964614E2ED228633D7485EF87AD7CBF27CE5B000",
#           "hash": "FEC974121AEE5D322D174E62CAD7FCE8572A1760C56B7231E772418F032625EF",
#           "metaData": {
#             "AffectedNodes": [
#               {
#                 "ModifiedNode": {
#                   "FinalFields": {
#                     "Account": "r3PDXzXky6gboMrwurmSCiUyhzdrFyAbfu",
#                     "Balance": "47607148",
#                     "Flags": 0,
#                     "OwnerCount": 16,
#                     "Sequence": 90597136
#                   },
#                   "LedgerEntryType": "AccountRoot",
#                   "LedgerIndex": "4CA84386D26EDA744A7C5080EC3101931AC2409461F3BB17A3178846B90F8A9C",
#                   "PreviousFields": {
#                     "Balance": "47607160",
#                     "Sequence": 90597135
#                   },
#                   "PreviousTxnID": "E73750E70E3FED5D99C99E7F0EC458801C313A6487339F741DBB0A1F63595C0F",
#                   "PreviousTxnLgrSeq": 90588710
#                 }
#               }
#             ],
#             "TransactionIndex": 32,
#             "TransactionResult": "tesSUCCESS"
#           }
#         }
#       ]
#     },
#     "status": "success"
#   },
#   "warnings": [
#     {
#       "id": 2001,
#       "message": "This is a clio server. clio only serves validated data. If you want to talk to rippled, include 'ledger_index':'current' in your request"
#     }
#   ]
# }
